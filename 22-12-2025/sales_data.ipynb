# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder\
.appName('sales data')\
.getOrCreate()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
raw_sales = [
    ("TXN001", "Delhi", "Laptop", "Electronics", 45000, "2024-01-05", "Complete"),
    ("TXN002", "Mumbai", "Mobile", "Electronics", 32000, "2024-01-05", "Complete"),
    ("TXN003", "Bangalore", "Tablet", "Electronics", 30000, "2024-01-06", "Complete"),
    ("TXN004", "Delhi", "Laptop", "Electronics", 0, "2024-01-07", "Cancelled"),
    ("TXN005", "Chennai", "Mobile", "Electronics", 0, "2024-01-08", "Complete"),
    ("TXN006", "Mumbai", "Tablet", "Electronics", 0, "2024-01-08", "Complete"),
    ("TXN007", "Delhi", "Laptop", "Electronics", 45000, "2024-01-09", "Complete"),
    ("TXN008", "Bangalore", "Mobile", "Electronics", 28000, "2024-01-09", "Complete"),
    ("TXN009", "Mumbai", "Laptop", "Electronics", 55000, "2024-01-10", "Complete")
]

columns = ["transaction_id", "city", "product", "category", "amount", "transaction_date", "status"]

# %%
schema = StructType([
    StructField("transaction_id", StringType(), True),
    StructField("city", StringType(), True),
    StructField("product", StringType(), True),
    StructField("category", StringType(), True),
    StructField("amount", StringType(), True),
    StructField("transaction_date", StringType(), True),
    StructField("status", StringType(), True)
])
raw_df = spark.createDataFrame(data=raw_sales, schema=schema)
raw_df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+---------+
# |transaction_id|     city|product|   category|amount|transaction_date|   status|
# +--------------+---------+-------+-----------+------+----------------+---------+
# |        TXN001|    Delhi| Laptop|Electronics| 45000|      2024-01-05| Complete|
# |        TXN002|   Mumbai| Mobile|Electronics| 32000|      2024-01-05| Complete|
# |        TXN003|Bangalore| Tablet|Electronics| 30000|      2024-01-06| Complete|
# |        TXN004|    Delhi| Laptop|Electronics|     0|      2024-01-07|Cancelled|
# |        TXN005|  Chennai| Mobile|Electronics|     0|      2024-01-08| Complete|
# |        TXN006|   Mumbai| Tablet|Electronics|     0|      2024-01-08| Complete|
# |        TXN007|    Delhi| Laptop|Electronics| 45000|      2024-01-09| Complete|
# |        TXN008|Bangalore| Mobile|Electronics| 28000|      2024-01-09| Complete|
# |        TXN009|   Mumbai| Laptop|Electronics| 55000|      2024-01-10| Complete|
# +--------------+---------+-------+-----------+------+----------------+---------+

# %% [markdown]
# #PART 1 — DATA CLEANING & TRANSFORMATION

# %% [markdown]
# 1. Trim and standardize all string columns

# %%
df = raw_df.select([trim(col(c)).alias(c) for c in raw_df.columns])
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+---------+
# |transaction_id|     city|product|   category|amount|transaction_date|   status|
# +--------------+---------+-------+-----------+------+----------------+---------+
# |        TXN001|    Delhi| Laptop|Electronics| 45000|      2024-01-05| Complete|
# |        TXN002|   Mumbai| Mobile|Electronics| 32000|      2024-01-05| Complete|
# |        TXN003|Bangalore| Tablet|Electronics| 30000|      2024-01-06| Complete|
# |        TXN004|    Delhi| Laptop|Electronics|     0|      2024-01-07|Cancelled|
# |        TXN005|  Chennai| Mobile|Electronics|     0|      2024-01-08| Complete|
# |        TXN006|   Mumbai| Tablet|Electronics|     0|      2024-01-08| Complete|
# |        TXN007|    Delhi| Laptop|Electronics| 45000|      2024-01-09| Complete|
# |        TXN008|Bangalore| Mobile|Electronics| 28000|      2024-01-09| Complete|
# |        TXN009|   Mumbai| Laptop|Electronics| 55000|      2024-01-10| Complete|
# +--------------+---------+-------+-----------+------+----------------+---------+

# %% [markdown]
# 2. Convert category to uppercase

# %%
df = df.withColumn("category", upper(col("category")))
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+---------+
# |transaction_id|     city|product|   category|amount|transaction_date|   status|
# +--------------+---------+-------+-----------+------+----------------+---------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05| Complete|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05| Complete|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06| Complete|
# |        TXN004|    Delhi| Laptop|ELECTRONICS|     0|      2024-01-07|Cancelled|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09| Complete|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09| Complete|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10| Complete|
# +--------------+---------+-------+-----------+------+----------------+---------+

# %% [markdown]
# 3. Convert amount to integer

# %%
df = df.withColumn("amount", col("amount").cast(IntegerType()))
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+---------+
# |transaction_id|     city|product|   category|amount|transaction_date|   status|
# +--------------+---------+-------+-----------+------+----------------+---------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05| Complete|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05| Complete|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06| Complete|
# |        TXN004|    Delhi| Laptop|ELECTRONICS|     0|      2024-01-07|Cancelled|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09| Complete|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09| Complete|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10| Complete|
# +--------------+---------+-------+-----------+------+----------------+---------+

# %% [markdown]
# 4. Handle invalid, empty, and null amount values

# %%
df = df.withColumn("amount", when(col("amount").isNull(), 0).otherwise(col("amount")))
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+---------+
# |transaction_id|     city|product|   category|amount|transaction_date|   status|
# +--------------+---------+-------+-----------+------+----------------+---------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05| Complete|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05| Complete|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06| Complete|
# |        TXN004|    Delhi| Laptop|ELECTRONICS|     0|      2024-01-07|Cancelled|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09| Complete|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09| Complete|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10| Complete|
# +--------------+---------+-------+-----------+------+----------------+---------+

# %% [markdown]
# 5. Convert transaction_date into DateType

# %%
df = df.withColumn("transaction_date",
                   coalesce(to_date(col("transaction_date"), "yyyy-MM-dd"),
                            to_date(col("transaction_date"), "dd-MM-yyyy"),
                            to_date(col("transaction_date"), "MM-dd-yyyy")
                            ))
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+---------+
# |transaction_id|     city|product|   category|amount|transaction_date|   status|
# +--------------+---------+-------+-----------+------+----------------+---------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05| Complete|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05| Complete|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06| Complete|
# |        TXN004|    Delhi| Laptop|ELECTRONICS|     0|      2024-01-07|Cancelled|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09| Complete|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09| Complete|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10| Complete|
# +--------------+---------+-------+-----------+------+----------------+---------+

# %% [markdown]
# 6. Remove duplicate transactions

# %%
df = df.dropDuplicates(["transaction_id"])
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+---------+
# |transaction_id|     city|product|   category|amount|transaction_date|   status|
# +--------------+---------+-------+-----------+------+----------------+---------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05| Complete|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05| Complete|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06| Complete|
# |        TXN004|    Delhi| Laptop|ELECTRONICS|     0|      2024-01-07|Cancelled|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08| Complete|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09| Complete|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09| Complete|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10| Complete|
# +--------------+---------+-------+-----------+------+----------------+---------+

# %% [markdown]
# 7. Keep only Completed transactions

# %%
df = df.filter(col("status") == "Complete")
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+--------+
# |transaction_id|     city|product|   category|amount|transaction_date|  status|
# +--------------+---------+-------+-----------+------+----------------+--------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05|Complete|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05|Complete|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06|Complete|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08|Complete|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08|Complete|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09|Complete|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09|Complete|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10|Complete|
# +--------------+---------+-------+-----------+------+----------------+--------+

# %% [markdown]
# 8. Rename all columns to snake_case

# %%
import re

def to_snake_case(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\\1_\\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\\1_\\2', s1).lower()

original_columns = df.columns
for col_name in original_columns:
    df = df.withColumnRenamed(col_name, to_snake_case(col_name))

df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+--------+
# |transaction_id|     city|product|   category|amount|transaction_date|  status|
# +--------------+---------+-------+-----------+------+----------------+--------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05|Complete|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05|Complete|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06|Complete|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08|Complete|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08|Complete|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09|Complete|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09|Complete|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10|Complete|
# +--------------+---------+-------+-----------+------+----------------+--------+

# %% [markdown]
# #PART 2 — COLUMN OPERATIONS

# %% [markdown]
# 9. Add a column tax_amount (18% of amount)

# %%
df = df.withColumn("tax_amount", col("amount")*0.18)
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+--------+----------+
# |transaction_id|     city|product|   category|amount|transaction_date|  status|tax_amount|
# +--------------+---------+-------+-----------+------+----------------+--------+----------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05|Complete|    8100.0|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05|Complete|    5760.0|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06|Complete|    5400.0|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08|Complete|       0.0|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08|Complete|       0.0|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09|Complete|    8100.0|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09|Complete|    5040.0|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10|Complete|    9900.0|
# +--------------+---------+-------+-----------+------+----------------+--------+----------+

# %% [markdown]
# 10. Add a column total_amount (amount + tax)

# %%
df = df.withColumn("total_amount", col("amount") + col("tax_amount"))
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+--------+----------+------------+
# |transaction_id|     city|product|   category|amount|transaction_date|  status|tax_amount|total_amount|
# +--------------+---------+-------+-----------+------+----------------+--------+----------+------------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05|Complete|    8100.0|     53100.0|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05|Complete|    5760.0|     37760.0|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06|Complete|    5400.0|     35400.0|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08|Complete|       0.0|         0.0|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08|Complete|       0.0|         0.0|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09|Complete|    8100.0|     53100.0|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09|Complete|    5040.0|     33040.0|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10|Complete|    9900.0|     64900.0|
# +--------------+---------+-------+-----------+------+----------------+--------+----------+------------+

# %% [markdown]
# 11. Replace city names with standardized values

# %%
from pyspark.sql.functions import when, col
df = df.withColumn("city",
                    when(col("city") == "Delhi", "Delhi")
                   .when(col("city") == "Mumbai", "Mumbai")
                   .when(col("city") == "Bangalore", "Bangalore")
                   .when(col("city") == "Chennai", "Chennai")
                   # Add more standardization rules here if needed
                   .otherwise(col("city"))) # Keep original if no match

df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------------+--------+----------+------------+
# |transaction_id|     city|product|   category|amount|transaction_date|  status|tax_amount|total_amount|
# +--------------+---------+-------+-----------+------+----------------+--------+----------+------------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-05|Complete|    8100.0|     53100.0|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|      2024-01-05|Complete|    5760.0|     37760.0|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|      2024-01-06|Complete|    5400.0|     35400.0|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|      2024-01-08|Complete|       0.0|         0.0|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|      2024-01-08|Complete|       0.0|         0.0|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|      2024-01-09|Complete|    8100.0|     53100.0|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|      2024-01-09|Complete|    5040.0|     33040.0|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|      2024-01-10|Complete|    9900.0|     64900.0|
# +--------------+---------+-------+-----------+------+----------------+--------+----------+------------+

# %% [markdown]
# 12. Rename transaction_date to order_date

# %%
df = df.withColumnRenamed("transaction_date", "order_date")
df.show()
# Out:
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+
# |transaction_id|     city|product|   category|amount|order_date|  status|tax_amount|total_amount|
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|2024-01-05|Complete|    8100.0|     53100.0|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|2024-01-05|Complete|    5760.0|     37760.0|
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|2024-01-06|Complete|    5400.0|     35400.0|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|2024-01-08|Complete|       0.0|         0.0|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|2024-01-08|Complete|       0.0|         0.0|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|2024-01-09|Complete|    8100.0|     53100.0|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|2024-01-09|Complete|    5040.0|     33040.0|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|2024-01-10|Complete|    9900.0|     64900.0|
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+

# %% [markdown]
# #PART 3 — ANALYTICS TRANSFORMATIONS

# %% [markdown]
# 13. Total revenue per city

# %%
df.groupBy("city").agg(sum("amount").alias("total_revenue")).show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|        58000|
# |  Chennai|            0|
# |   Mumbai|        87000|
# |    Delhi|        90000|
# +---------+-------------+

# %% [markdown]
# 14. Total revenue per product

# %%
df.groupBy("product").agg(sum("amount").alias("total_revenue")).show()
# Out:
# +-------+-------------+
# |product|total_revenue|
# +-------+-------------+
# | Laptop|       145000|
# | Mobile|        60000|
# | Tablet|        30000|
# +-------+-------------+

# %% [markdown]
# 15. Average order value per city

# %%
df.groupBy("city").agg(avg("amount").alias("avg_order_value")).show()
# Out:
# +---------+---------------+
# |     city|avg_order_value|
# +---------+---------------+
# |Bangalore|        29000.0|
# |  Chennai|            0.0|
# |   Mumbai|        29000.0|
# |    Delhi|        45000.0|
# +---------+---------------+

# %% [markdown]
# 16. Top 3 cities by revenue

# %%
df.groupBy("city").agg(sum("amount").alias("total_revenue")).orderBy(col("total_revenue").desc()).limit(3).show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |    Delhi|        90000|
# |   Mumbai|        87000|
# |Bangalore|        58000|
# +---------+-------------+

# %% [markdown]
# 17. Identify products with average amount > 40,000

# %%
df.groupBy("product").agg(avg("amount").alias("avg_amount")).filter(col("avg_amount") > 40000).show()
# Out:
# +-------+------------------+
# |product|        avg_amount|
# +-------+------------------+
# | Laptop|48333.333333333336|
# +-------+------------------+

# %% [markdown]
# #PART 4 — PARTITIONS & PERFORMANCE

# %% [markdown]
# 18. Check current number of partitions

# %%
df.rdd.getNumPartitions()
# Out:
# 1

# %% [markdown]
# 19. Repartition data by city

# %%
df = df.repartition("city")
df.rdd.getNumPartitions()
# Out:
# 1

# %% [markdown]
# 20. Explain why repartitioning is needed

# %%
# Repartitioning is crucial in Apache Spark for several reasons, primarily related to performance optimization
# and efficient resource utilization in a distributed computing environment:
#
# 1.  **Optimize Shuffle Operations and Prevent Data Skew**: When performing wide transformations like `groupBy`,
#     `join`, or `orderBy`, Spark shuffles data across the network to group it by keys. If data is unevenly
#     distributed across partitions (data skew), some partitions will have significantly more data than others.
#     This leads to a few tasks taking a much longer time to complete, becoming bottlenecks and slowing down
#     the entire Spark job. Repartitioning can redistribute the data more evenly across the cluster, mitigating
#     data skew and improving the performance of shuffle operations.
#
# 2.  **Improve Parallelism**: If the number of partitions is too low, Spark might not be able to fully utilize
#     all available CPU cores and executors in the cluster. Increasing the number of partitions (within reasonable
#     limits) allows more tasks to run in parallel, thereby speeding up computations.
#
# 3.  **Reduce Task Overhead for Small Partitions**: Conversely, if there are too many very small partitions,
#     the overhead of managing and scheduling a large number of tiny tasks can outweigh the benefits of parallelism.
#     Each task incurs a certain overhead, so having an optimal number of partitions, where each partition is a
#     manageable size (e.g., 128MB-256MB), is important.
#
# 4.  **Achieve Data Locality**: Repartitioning by a specific key that will be used in subsequent operations (like
#     a `join` or `filter`) can help ensure that all data related to that key resides on the same physical node.
#     This reduces network I/O, as Spark can perform operations on locally available data instead of fetching
#     it from other nodes.
#
# In summary, while repartitioning involves a costly shuffle operation itself, it is often a necessary step
# to improve the overall performance of subsequent transformations, especially on large datasets where data
# distribution and parallelism are critical factors.

# %% [markdown]
# 21. Use explain(True) and observe the plan

# %%
df.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'RepartitionByExpression ['city]
# +- Project [transaction_id#314, city#667, product#316, category#317, amount#318, transaction_date#319 AS order_date#756, status#320, tax_amount#403, total_amount#489]
#    +- Project [transaction_id#314, CASE WHEN (city#578 = Delhi) THEN Delhi WHEN (city#578 = Mumbai) THEN Mumbai WHEN (city#578 = Bangalore) THEN Bangalore WHEN (city#578 = Chennai) THEN Chennai ELSE city#578 END AS city#667, product#316, category#317, amount#318, transaction_date#319, status#320, tax_amount#403, total_amount#489]
#       +- Project [transaction_id#314, CASE WHEN (city#315 = Delhi) THEN Delhi WHEN (city#315 = Mumbai) THEN Mumbai WHEN (city#315 = Bangalore) THEN Bangalore WHEN (city#315 = Chennai) THEN Chennai ELSE city#315 END AS city#578, product#316, category#317, amount#318, transaction_date#319, status#320, tax_amount#403, total_amount#489]
#          +- Project [transaction_id#314, city#315, product#316, category#317, amount#318, transaction_date#319, status#320, tax_amount#403, (cast(amount#318 as double) + tax_amount#403) AS total_amount#489]
#             +- Project [transaction_id#314, city#315, product#316, category#317, amount#318, transaction_date#319, status#320, (cast(amount#318 as double) * 0.18) AS tax_amount#403]
#                +- Project [transaction_id#314, city#315, product#316, category#317, amount#318, transaction_date#319, status#35 AS status#320]
#                   +- Project [transaction_id#314, city#315, product#316, category#317, amount#318, transaction_date#127 AS transaction_date#319, status#35]
#                      +- Project [transaction_id#314, city#315, product#316, category#317, amount#104 AS amount#318, transaction_date#127, status#35]
#                         +- Project [transaction_id#314, city#315, product#316, category#58 AS category#317, amount#104, transaction_date#127, status#35]
#                            +- Project [transaction_id#314, city#315, product#31 AS product#316, category#58, amount#104, transaction_date#127, status#35]
#                               +- Project [transaction_id#314, city#30 AS city#315, product#31, category#58, amount#104, transaction_date#127, status#35]
#                                  +- Project [transaction_id#29 AS transaction_id#314, city#30, product#31, category#58, amount#104, transaction_date#127, status#35]
#                                     +- Filter (status#35 = Complete)
#                                        +- Deduplicate [transaction_id#29]
#                                           +- Project [transaction_id#29, city#30, product#31, category#58, amount#104, coalesce(to_date(transaction_date#34, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(transaction_date#34, Some(dd-MM-yyyy), Some(Etc/UTC), true), to_date(transaction_date#34, Some(MM-dd-yyyy), Some(Etc/UTC), true)) AS transaction_date#127, status#35]
#                                              +- Project [transaction_id#29, city#30, product#31, category#58, CASE WHEN isnull(amount#81) THEN 0 ELSE amount#81 END AS amount#104, transaction_date#34, status#35]
#                                                 +- Project [transaction_id#29, city#30, product#31, category#58, cast(amount#33 as int) AS amount#81, transaction_date#34, status#35]
#                                                    +- Project [transaction_id#29, city#30, product#31, upper(category#32) AS category#58, amount#33, transaction_date#34, status#35]
#                                                       +- Project [trim(transaction_id#0, None) AS transaction_id#29, trim(city#1, None) AS city#30, trim(product#2, None) AS product#31, trim(category#3, None) AS category#32, trim(amount#4, None) AS amount#33, trim(transaction_date#5, None) AS transaction_date#34, trim(status#6, None) AS status#35]
#                                                          +- LogicalRDD [transaction_id#0, city#1, product#2, category#3, amount#4, transaction_date#5, status#6], false
#
# == Analyzed Logical Plan ==
# transaction_id: string, city: string, product: string, category: string, amount: int, order_date: date, status: string, tax_amount: double, total_amount: double
# RepartitionByExpression [city#667]
# +- Project [transaction_id#314, city#667, product#316, category#317, amount#318, transaction_date#319 AS order_date#756, status#320, tax_amount#403, total_amount#489]
#    +- Project [transaction_id#314, CASE WHEN (city#578 = Delhi) THEN Delhi WHEN (city#578 = Mumbai) THEN Mumbai WHEN (city#578 = Bangalore) THEN Bangalore WHEN (city#578 = Chennai) THEN Chennai ELSE city#578 END AS city#667, product#316, category#317, amount#318, transaction_date#319, status#320, tax_amount#403, total_amount#489]
#       +- Project [transaction_id#314, CASE WHEN (city#315 = Delhi) THEN Delhi WHEN (city#315 = Mumbai) THEN Mumbai WHEN (city#315 = Bangalore) THEN Bangalore WHEN (city#315 = Chennai) THEN Chennai ELSE city#315 END AS city#578, product#316, category#317, amount#318, transaction_date#319, status#320, tax_amount#403, total_amount#489]
#          +- Project [transaction_id#314, city#315, product#316, category#317, amount#318, transaction_date#319, status#320, tax_amount#403, (cast(amount#318 as double) + tax_amount#403) AS total_amount#489]
#             +- Project [transaction_id#314, city#315, product#316, category#317, amount#318, transaction_date#319, status#320, (cast(amount#318 as double) * 0.18) AS tax_amount#403]
#                +- Project [transaction_id#314, city#315, product#316, category#317, amount#318, transaction_date#319, status#35 AS status#320]
#                   +- Project [transaction_id#314, city#315, product#316, category#317, amount#318, transaction_date#127 AS transaction_date#319, status#35]
#                      +- Project [transaction_id#314, city#315, product#316, category#317, amount#104 AS amount#318, transaction_date#127, status#35]
#                         +- Project [transaction_id#314, city#315, product#316, category#58 AS category#317, amount#104, transaction_date#127, status#35]
#                            +- Project [transaction_id#314, city#315, product#31 AS product#316, category#58, amount#104, transaction_date#127, status#35]
#                               +- Project [transaction_id#314, city#30 AS city#315, product#31, category#58, amount#104, transaction_date#127, status#35]
#                                  +- Project [transaction_id#29 AS transaction_id#314, city#30, product#31, category#58, amount#104, transaction_date#127, status#35]
#                                     +- Filter (status#35 = Complete)
#                                        +- Deduplicate [transaction_id#29]
#                                           +- Project [transaction_id#29, city#30, product#31, category#58, amount#104, coalesce(to_date(transaction_date#34, Some(yyyy-MM-dd), Some(Etc/UTC), true), to_date(transaction_date#34, Some(dd-MM-yyyy), Some(Etc/UTC), true), to_date(transaction_date#34, Some(MM-dd-yyyy), Some(Etc/UTC), true)) AS transaction_date#127, status#35]
#                                              +- Project [transaction_id#29, city#30, product#31, category#58, CASE WHEN isnull(amount#81) THEN 0 ELSE amount#81 END AS amount#104, transaction_date#34, status#35]
#                                                 +- Project [transaction_id#29, city#30, product#31, category#58, cast(amount#33 as int) AS amount#81, transaction_date#34, status#35]
#                                                    +- Project [transaction_id#29, city#30, product#31, upper(category#32) AS category#58, amount#33, transaction_date#34, status#35]
#                                                       +- Project [trim(transaction_id#0, None) AS transaction_id#29, trim(city#1, None) AS city#30, trim(product#2, None) AS product#31, trim(category#3, None) AS category#32, trim(amount#4, None) AS amount#33, trim(transaction_date#5, None) AS transaction_date#34, trim(status#6, None) AS status#35]
#                                                          +- LogicalRDD [transaction_id#0, city#1, product#2, category#3, amount#4, transaction_date#5, status#6], false
#
# == Optimized Logical Plan ==
# RepartitionByExpression [city#667]
# +- Project [transaction_id#29, CASE WHEN (city#578 = Delhi) THEN Delhi WHEN (city#578 = Mumbai) THEN Mumbai WHEN (city#578 = Bangalore) THEN Bangalore WHEN (city#578 = Chennai) THEN Chennai ELSE city#578 END AS city#667, product#1273, category#1275, amount#1277, transaction_date#1279 AS order_date#756, status#1281, tax_amount#403, total_amount#489]
#    +- Project [transaction_id#29, CASE WHEN (city#1271 = Delhi) THEN Delhi WHEN (city#1271 = Mumbai) THEN Mumbai WHEN (city#1271 = Bangalore) THEN Bangalore WHEN (city#1271 = Chennai) THEN Chennai ELSE city#1271 END AS city#578, product#1273, category#1275, amount#1277, transaction_date#1279, status#1281, tax_amount#403, (cast(amount#1277 as double) + tax_amount#403) AS total_amount#489]
#       +- Project [transaction_id#29, city#1271, product#1273, category#1275, amount#1277, transaction_date#1279, status#1281, (cast(amount#1277 as double) * 0.18) AS tax_amount#403]
#          +- Filter (isnotnull(status#1281) AND (status#1281 = Complete))
#             +- Aggregate [transaction_id#29], [transaction_id#29, first(city#30, false) AS city#1271, first(product#31, false) AS product#1273, first(category#58, false) AS category#1275, first(amount#104, false) AS amount#1277, first(transaction_date#127, false) AS transaction_date#1279, first(status#35, false) AS status#1281]
#                +- Project [transaction_id#29, city#30, product#31, category#58, CASE WHEN isnull(amount#81) THEN 0 ELSE amount#81 END AS amount#104, coalesce(cast(gettimestamp(transaction_date#34, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(transaction_date#34, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(transaction_date#34, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date)) AS transaction_date#127, status#35]
#                   +- Project [trim(transaction_id#0, None) AS transaction_id#29, trim(city#1, None) AS city#30, trim(product#2, None) AS product#31, upper(trim(category#3, None)) AS category#58, cast(trim(amount#4, None) as int) AS amount#81, trim(transaction_date#5, None) AS transaction_date#34, trim(status#6, None) AS status#35]
#                      +- LogicalRDD [transaction_id#0, city#1, product#2, category#3, amount#4, transaction_date#5, status#6], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    ResultQueryStage 2
#    +- AQEShuffleRead coalesced
#       +- ShuffleQueryStage 1
#          +- Exchange hashpartitioning(city#667, 200), REPARTITION_BY_COL, [plan_id=1944]
#             +- *(3) Project [transaction_id#29, CASE WHEN (city#578 = Delhi) THEN Delhi WHEN (city#578 = Mumbai) THEN Mumbai WHEN (city#578 = Bangalore) THEN Bangalore WHEN (city#578 = Chennai) THEN Chennai ELSE city#578 END AS city#667, product#1273, category#1275, amount#1277, transaction_date#1279 AS order_date#756, status#1281, tax_amount#403, total_amount#489]
#                +- *(3) Project [transaction_id#29, CASE WHEN (city#1271 = Delhi) THEN Delhi WHEN (city#1271 = Mumbai) THEN Mumbai WHEN (city#1271 = Bangalore) THEN Bangalore WHEN (city#1271 = Chennai) THEN Chennai ELSE city#1271 END AS city#578, product#1273, category#1275, amount#1277, transaction_date#1279, status#1281, tax_amount#403, (cast(amount#1277 as double) + tax_amount#403) AS total_amount#489]
#                   +- *(3) Project [transaction_id#29, city#1271, product#1273, category#1275, amount#1277, transaction_date#1279, status#1281, (cast(amount#1277 as double) * 0.18) AS tax_amount#403]
#                      +- *(3) Filter (isnotnull(status#1281) AND (status#1281 = Complete))
#                         +- SortAggregate(key=[transaction_id#29], functions=[first(city#30, false), first(product#31, false), first(category#58, false), first(amount#104, false), first(transaction_date#127, false), first(status#35, false)], output=[transaction_id#29, city#1271, product#1273, category#1275, amount#1277, transaction_date#1279, status#1281])
#                            +- *(2) Sort [transaction_id#29 ASC NULLS FIRST], false, 0
#                               +- AQEShuffleRead coalesced
#                                  +- ShuffleQueryStage 0
#                                     +- Exchange hashpartitioning(transaction_id#29, 200), ENSURE_REQUIREMENTS, [plan_id=1882]
#                                        +- SortAggregate(key=[transaction_id#29], functions=[partial_first(city#30, false), partial_first(product#31, false), partial_first(category#58, false), partial_first(amount#104, false), partial_first(transaction_date#127, false), partial_first(status#35, false)], output=[transaction_id#29, first#1294, valueSet#1295, first#1296, valueSet#1297, first#1298, valueSet#1299, first#1300, valueSet#1301, first#1302, valueSet#1303, first#1304, valueSet#1305])
#                                           +- *(1) Sort [transaction_id#29 ASC NULLS FIRST], false, 0
#                                              +- *(1) Project [transaction_id#29, city#30, product#31, category#58, CASE WHEN isnull(amount#81) THEN 0 ELSE amount#81 END AS amount#104, coalesce(cast(gettimestamp(transaction_date#34, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(transaction_date#34, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(transaction_date#34, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date)) AS transaction_date#127, status#35]
#                                                 +- *(1) Project [trim(transaction_id#0, None) AS transaction_id#29, trim(city#1, None) AS city#30, trim(product#2, None) AS product#31, upper(trim(category#3, None)) AS category#58, cast(trim(amount#4, None) as int) AS amount#81, trim(transaction_date#5, None) AS transaction_date#34, trim(status#6, None) AS status#35]
#                                                    +- *(1) Scan ExistingRDD[transaction_id#0,city#1,product#2,category#3,amount#4,transaction_date#5,status#6]
# +- == Initial Plan ==
#    Exchange hashpartitioning(city#667, 200), REPARTITION_BY_COL, [plan_id=1853]
#    +- Project [transaction_id#29, CASE WHEN (city#578 = Delhi) THEN Delhi WHEN (city#578 = Mumbai) THEN Mumbai WHEN (city#578 = Bangalore) THEN Bangalore WHEN (city#578 = Chennai) THEN Chennai ELSE city#578 END AS city#667, product#1273, category#1275, amount#1277, transaction_date#1279 AS order_date#756, status#1281, tax_amount#403, total_amount#489]
#       +- Project [transaction_id#29, CASE WHEN (city#1271 = Delhi) THEN Delhi WHEN (city#1271 = Mumbai) THEN Mumbai WHEN (city#1271 = Bangalore) THEN Bangalore WHEN (city#1271 = Chennai) THEN Chennai ELSE city#1271 END AS city#578, product#1273, category#1275, amount#1277, transaction_date#1279, status#1281, tax_amount#403, (cast(amount#1277 as double) + tax_amount#403) AS total_amount#489]
#          +- Project [transaction_id#29, city#1271, product#1273, category#1275, amount#1277, transaction_date#1279, status#1281, (cast(amount#1277 as double) * 0.18) AS tax_amount#403]
#             +- Filter (isnotnull(status#1281) AND (status#1281 = Complete))
#                +- SortAggregate(key=[transaction_id#29], functions=[first(city#30, false), first(product#31, false), first(category#58, false), first(amount#104, false), first(transaction_date#127, false), first(status#35, false)], output=[transaction_id#29, city#1271, product#1273, category#1275, amount#1277, transaction_date#1279, status#1281])
#                   +- Sort [transaction_id#29 ASC NULLS FIRST], false, 0
#                      +- Exchange hashpartitioning(transaction_id#29, 200), ENSURE_REQUIREMENTS, [plan_id=1846]
#                         +- SortAggregate(key=[transaction_id#29], functions=[partial_first(city#30, false), partial_first(product#31, false), partial_first(category#58, false), partial_first(amount#104, false), partial_first(transaction_date#127, false), partial_first(status#35, false)], output=[transaction_id#29, first#1294, valueSet#1295, first#1296, valueSet#1297, first#1298, valueSet#1299, first#1300, valueSet#1301, first#1302, valueSet#1303, first#1304, valueSet#1305])
#                            +- Sort [transaction_id#29 ASC NULLS FIRST], false, 0
#                               +- Project [transaction_id#29, city#30, product#31, category#58, CASE WHEN isnull(amount#81) THEN 0 ELSE amount#81 END AS amount#104, coalesce(cast(gettimestamp(transaction_date#34, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(transaction_date#34, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date), cast(gettimestamp(transaction_date#34, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date)) AS transaction_date#127, status#35]
#                                  +- Project [trim(transaction_id#0, None) AS transaction_id#29, trim(city#1, None) AS city#30, trim(product#2, None) AS product#31, upper(trim(category#3, None)) AS category#58, cast(trim(amount#4, None) as int) AS amount#81, trim(transaction_date#5, None) AS transaction_date#34, trim(status#6, None) AS status#35]
#                                     +- Scan ExistingRDD[transaction_id#0,city#1,product#2,category#3,amount#4,transaction_date#5,status#6]

# %% [markdown]
# #PART 5 — FILE FORMAT STORAGE (HANDS-ON)

# %% [markdown]
# 22. Write cleaned data to Parquet
#
# data/parquet/sales

# %%
df.write.mode("overwrite").parquet("data/parquet/sales")

# %% [markdown]
# 23. Read Parquet back and validate schema

# %%
parquet_df = spark.read.parquet("data/parquet/sales")
parquet_df.printSchema()
parquet_df.show()
# Out:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- amount: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- status: string (nullable = true)
#  |-- tax_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+
# |transaction_id|     city|product|   category|amount|order_date|  status|tax_amount|total_amount|
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|2024-01-06|Complete|    5400.0|     35400.0|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|2024-01-09|Complete|    5040.0|     33040.0|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|2024-01-08|Complete|       0.0|         0.0|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|2024-01-05|Complete|    5760.0|     37760.0|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|2024-01-08|Complete|       0.0|         0.0|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|2024-01-10|Complete|    9900.0|     64900.0|
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|2024-01-05|Complete|    8100.0|     53100.0|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|2024-01-09|Complete|    8100.0|     53100.0|
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+

# %% [markdown]
# 24. Write the same data to ORC
#
# data/orc/sales

# %%
df.write.mode("overwrite").orc("data/orc/sales")

# %%
df_orc = spark.read.orc("data/orc/sales")
df_orc.show()
# Out:
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+
# |transaction_id|     city|product|   category|amount|order_date|  status|tax_amount|total_amount|
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+
# |        TXN003|Bangalore| Tablet|ELECTRONICS| 30000|2024-01-06|Complete|    5400.0|     35400.0|
# |        TXN008|Bangalore| Mobile|ELECTRONICS| 28000|2024-01-09|Complete|    5040.0|     33040.0|
# |        TXN005|  Chennai| Mobile|ELECTRONICS|     0|2024-01-08|Complete|       0.0|         0.0|
# |        TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|2024-01-05|Complete|    5760.0|     37760.0|
# |        TXN006|   Mumbai| Tablet|ELECTRONICS|     0|2024-01-08|Complete|       0.0|         0.0|
# |        TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|2024-01-10|Complete|    9900.0|     64900.0|
# |        TXN001|    Delhi| Laptop|ELECTRONICS| 45000|2024-01-05|Complete|    8100.0|     53100.0|
# |        TXN007|    Delhi| Laptop|ELECTRONICS| 45000|2024-01-09|Complete|    8100.0|     53100.0|
# +--------------+---------+-------+-----------+------+----------+--------+----------+------------+

# %% [markdown]
# 25. Compare file sizes and number of output files

# %%
import os

# Function to get directory size and file count
def get_directory_info(path):
    total_size = 0
    file_count = 0
    if os.path.exists(path):
        for dirpath, dirnames, filenames in os.walk(path):
            for f in filenames:
                fp = os.path.join(dirpath, f)
                # Skip metadata files if they exist
                if not f.startswith('.') and not f.startswith('_'):
                    total_size += os.path.getsize(fp)
                    file_count += 1
    return total_size, file_count

parquet_path = "data/parquet/sales"
orc_path = "data/orc/sales"

parquet_size, parquet_files = get_directory_info(parquet_path)
orc_size, orc_files = get_directory_info(orc_path)

print(f"Parquet directory: {parquet_path}")
print(f"  Total size: {parquet_size / (1024*1024):.2f} MB")
print(f"  Number of data files: {parquet_files}")

print(f"\nORC directory: {orc_path}")
print(f"  Total size: {orc_size / (1024*1024):.2f} MB")
print(f"  Number of data files: {orc_files}")
# Out:
# Parquet directory: data/parquet/sales
#   Total size: 0.00 MB
#   Number of data files: 1
#
# ORC directory: data/orc/sales
#   Total size: 0.00 MB
#   Number of data files: 1
